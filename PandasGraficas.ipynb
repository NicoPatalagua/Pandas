# %% [markdown]
# Nicolás Patalagua Suárez

# %%
import matplotlib.pyplot as plt
labels=['Humanidades','Educacion','Quimica Analitica','Lengua Extranjera','Ciencias Computacionales','Ingenieria','Matematicas','Biologia','Fisica']
values=[8.0,7.0,7.0,4.0,21.0,19.0,15.0,10.0,9.0]
colors=['b','g','r','c','m','y','k','w']
explode=[0,0,0,0,0,0.3,0,0,0]
plt.title('Porcentaje Asignaturas')
plt.pie(values,labels= labels,colors=colors,explode=explode, shadow = True, autopct = '%1.1f%%', startangle=180)
#shadow = True, autopct = '%1.1f%%', startangle=180
plt.axis('equal')
# Out:
# (-1.1147585464995564,
#  1.4099294764906851,
#  -1.101211270375271,
#  1.1109660290424086)

# %%
import csv
import numpy as np

with open('info_estudiantes.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(["Genero", "TV", "Computador","Dormir","AlturaE","AlturaMama","AlturaPapa","EjercicioE","Promedio"])
    for i in range (180):
      gen=np.random.randint(0,2)
      if gen == 1:
         genero='Male'
      elif gen==0:
        genero='Female'
      tv = np.random.randint(0,12)
      com = np.random.randint(0,18)
      dor = np.random.randint(0,9)
      Alte = np.random.randint(100,192)
      Altm = np.random.randint(100,169)
      Altp = np.random.randint(100,192)
      ejer = np.random.randint(0,9)
      prom = np.random.uniform(3,5)
      writer.writerow([genero,tv,com,dor,Alte,Altm,Altp,ejer,prom])

# %%
import pandas as pd
import seaborn as sns
students = pd.read_csv("info_estudiantes.csv")
g = sns.FacetGrid(students, palette='Set1', size=7)
g.map(plt.scatter, "AlturaMama", "AlturaE",s=140, linewidth =7, edgecolor="#15004f",color = "#68c600")
g.set_axis_labels("Mothers Height","Students Height")
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:243: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
students1 = pd.read_csv("info_estudiantes.csv")
g = sns.FacetGrid(students1, palette='Set1', size=7)
g.map(plt.scatter, "TV", "Promedio",s=140, linewidth =7, edgecolor="#39ff00",color = "#e90202")
g.set_axis_labels("Horas TV","Promedio")
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:243: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
students2 = pd.read_csv("info_estudiantes.csv")
g = sns.FacetGrid(students2, palette='Set1', size=7)
g.map(plt.scatter, "Computador", "Promedio",s=140, linewidth =7, edgecolor="#1799cc",color = "#d6ff00")
g.set_axis_labels("Horas Computador","Promedio")
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:243: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.set(style="whitegrid")
altura=pd.read_csv("info_estudiantes.csv")
x = altura.AlturaE
y = altura.AlturaMama
z = altura.AlturaMama
cm= plt.cm.get_cmap('RdYlGn')
fig, ax = plt.subplots(figsize=(12,10))
sc = ax.scatter(x,y,s=z*3,c=z,cmap=cm, linewidth=0.2, alpha=0.5)
ax.grid()
fig.colorbar(sc)
ax.set_xlabel("Altura Estudiante", fontsize=14)
ax.set_ylabel("Altura Mamá", fontsize=14)
plt.show()

# %%
from numpy.random import randn
import matplotlib as mpl
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_palette("hls")
mpl.rc("figure",figsize=(10,6))
data=randn(250)
plt.title("KDE demonstration using Seaborn and Matplotlib",fontsize=20)
sns.distplot(data,color='#1799cc')

# %%
from scipy.stats.kde import gaussian_kde
from scipy.stats import norm
from numpy import linspace, hstack
from pylab import plot,show,hist
sample1=norm.rvs(loc=-1.0,scale=1,size=320)
sample2=norm.rvs(loc=2.0,scale=0.6,size=320)
sample=hstack([sample1,sample2])
probDensityFun=gaussian_kde(sample)
plt.title("KDE Demosntration using Scipy and Numpy",fontsize=20)
x=linspace(-5,5,200)
plot(x,probDensityFun(x),'r')
hist(sample, normed=1,alpha=0.45,color='#e90202')
show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   if sys.path[0] == '':
